# %% [markdown]
# # 0. Configuration

# %%
# links to shared data MovieLens
# source on kaggle: https://www.kaggle.com/code/quangnhatbui/movie-recommender/data
MOVIES_METADATA_URL = 'https://drive.google.com/file/d/19g6-apYbZb5D-wRj4L7aYKhxS-fDM4Fb/view?usp=share_link'

# %% [markdown]
# # 1. Modules and functions

# %%
pip install pymystem3
# Out:
# Requirement already satisfied: pymystem3 in /Users/vydolga/.pyenv/versions/3.9.16/lib/python3.9/site-packages (0.2.0)
# Requirement already satisfied: requests in /Users/vydolga/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from pymystem3) (2.28.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vydolga/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from requests->pymystem3) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/vydolga/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from requests->pymystem3) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vydolga/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from requests->pymystem3) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/vydolga/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from requests->pymystem3) (3.0.1)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/Users/vydolga/.pyenv/versions/3.9.16/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
import nltk
import numpy as np
import pandas as pd
from tqdm import tqdm_notebook
from ast import literal_eval
from pymystem3 import Mystem
from string import punctuation
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

import warnings
warnings.filterwarnings('ignore')

# download stop words beforehand
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/vydolga/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## 1.1. Helper functions to avoid copypaste

# %%
def read_csv_from_gdrive(url):
    """
    gets csv data from a given url (taken from file -> share -> copy link)
    :url: example https://drive.google.com/file/d/1BlZfCLLs5A13tbNSJZ1GPkHLWQOnPlE4/view?usp=share_link
    """
    file_id = url.split('/')[-2]
    file_path = 'https://drive.google.com/uc?export=download&id=' + file_id
    data = pd.read_csv(file_path)

    return data

# %%
# init lemmatizer to avoid slow performance
mystem = Mystem() 

def word_tokenize_clean(doc: str, stop_words: list):
    '''
    tokenize from string to list of words
    '''

    # split into lower case word tokens \w lemmatization
    tokens = list(set(mystem.lemmatize(doc.lower())))
  
    # remove tokens that are not alphabetic (including punctuation) and not a stop word
    tokens = [word for word in tokens if word.isalpha() and not word in stop_words \
              not in list(punctuation)]
    return tokens

# %% [markdown]
# # 2. Main

# %% [markdown]
# ## 2.1. Data Preparation

# %%
# read csv information about films etc
movies_metadata = read_csv_from_gdrive(MOVIES_METADATA_URL)
movies_metadata.head(3)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
#
#      original_title                                           overview  ...  \
# 0         Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 1           Jumanji  When siblings Judy and Peter discover an encha...  ...
# 2  Grumpier Old Men  A family wedding reignites the ancient feud be...  ...
#
#   release_date      revenue runtime  \
# 0   1995-10-30  373554033.0    81.0
# 1   1995-12-15  262797249.0   104.0
# 2   1995-12-22          0.0   101.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline             title  video  \
# 0                                                NaN         Toy Story  False
# 1          Roll the dice and unleash the excitement!           Jumanji  False
# 2  Still Yelling. Still Fighting. Still Ready for...  Grumpier Old Men  False
#
#   vote_average vote_count
# 0          7.7     5415.0
# 1          6.9     2413.0
# 2          6.5       92.0
#
# [3 rows x 24 columns]

# %%
# let's see what columns we have
movies_metadata.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# To get accurate results we need to preprocess text a bit. The pipeline will be as follows:
#
# - Filter only necessary columns from movies_metadada : id, original_title, overview;
# - Define `model_index` for model to match back with `id` column;
# - Text cleaning: removing stopwords & punctuation, lemmatization for further tokenization and tagged document creatin required for gensim.Doc2Vec

# %%
# filter cols
sample = movies_metadata[['id', 'original_title', 'overview','tagline']].copy()
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              45466 non-null  object
#  1   original_title  45466 non-null  object
#  2   overview        44512 non-null  object
#  3   tagline         20412 non-null  object
# dtypes: object(4)
# memory usage: 1.4+ MB

# %%
# as you see from above, we have missing overview in some cases -- let's fill it with the original title
sample.loc[sample['overview'].isnull(), 'overview'] = sample.loc[sample['overview'].isnull(), 'original_title']
sample.loc[sample['tagline'].isnull(), 'tagline'] = sample.loc[sample['tagline'].isnull(), 'original_title']

sample.isnull().sum()
# Out:
# id                0
# original_title    0
# overview          0
# tagline           0
# dtype: int64

# %%
# define model_index and make it as string
sample = sample.reset_index().rename(columns = {'index': 'model_index'})
sample['model_index'] = sample['model_index'].astype(str)

# %%
# create mapper with title and model_idnex to use it further in evaluation
movies_inv_mapper_up = {}
k=0
movies_inv_mapper = dict(zip(sample['original_title'].str.lower(), sample['model_index'].astype(int)))
for i in movies_inv_mapper:
    movies_inv_mapper_up[i] = [k, k+1, k+2]
    k=k+3
    # movies_inv_mapper_up[i] = k
    # k=k+1
    # movies_inv_mapper_up[i] = k
    # k=k+1
movies_inv_mapper_up
# Out:
# {'toy story': [0, 1, 2],
#  'jumanji': [3, 4, 5],
#  'grumpier old men': [6, 7, 8],
#  'waiting to exhale': [9, 10, 11],
#  'father of the bride part ii': [12, 13, 14],
#  'heat': [15, 16, 17],
#  'sabrina': [18, 19, 20],
#  'tom and huck': [21, 22, 23],
#  'sudden death': [24, 25, 26],
#  'goldeneye': [27, 28, 29],
#  'the american president': [30, 31, 32],
#  'dracula: dead and loving it': [33, 34, 35],
#  'balto': [36, 37, 38],
#  'nixon': [39, 40, 41],
#  'cutthroat island': [42, 43, 44],
#  'casino': [45, 46, 47],
#  'sense and sensibility': [48, 49, 50],
#  'four rooms': [51, 52, 53],
#  'ace ventura: when nature calls': [54, 55, 56],
#  'money train': [57, 58, 59],
#  'get shorty': [60, 61, 62],
#  'copycat': [63, 64, 65],
#  'assassins': [66, 67, 68],
#  'powder': [69, 70, 71],
#  'leaving las vegas': [72, 73, 74],
#  'othello': [75, 76, 77],
#  'now and then': [78, 79, 80],
#  'persuasion': [81, 82, 83],
#  'la cité des enfants perdus': [84, 85, 86],
#  '摇啊摇，摇到外婆桥': [87, 88, 89],
#  'dangerous minds': [90, 91, 92],
#  'twelve monkeys': [93, 94, 95],
#  'guillaumet, les ailes du courage': [96, 97, 98],
#  'babe': [99, 100, 101],
#  'carrington': [102, 103, 104],
#  'dead man walking': [105, 106, 107],
#  'across the sea of time': [108, 109, 110],
#  'it takes two': [111, 112, 113],
#  'clueless': [114, 115, 116],
#  'cry, the beloved country': [117, 118, 119],
#  'richard iii': [120, 121, 122],
#  'dead presidents': [123, 124, 125],
#  'restoration': [126, 127, 128],
#  'mortal kombat': [129, 130, 131],
#  'to die for': [132, 133, 134],
#  'how to make an american quilt': [135, 136, 137],
#  'se7en': [138, 139, 140],
#  'pocahontas': [141, 142, 143],
#  'when night is falling': [144, 145, 146],
#  'the usual suspects': [147, 148, 149],
#  'guardian angel': [150, 151, 152],
#  'mighty aphrodite': [153, 154, 155],
#  'lamerica': [156, 157, 158],
#  'the big green': [159, 160, 161],
#  'georgia': [162, 163, 164],
#  'kids of the round table': [165, 166, 167],
#  'home for the holidays': [168, 169, 170],
#  'il postino': [171, 172, 173],
#  'le confessionnal': [174, 175, 176],
#  'the indian in the cupboard': [177, 178, 179],
#  'eye for an eye': [180, 181, 182],
#  "mr. holland's opus": [183, 184, 185],
#  "don't be a menace to south central while drinking your juice in the hood": [186,
#   187,
#   188],
#  'two if by sea': [189, 190, 191],
#  'bio-dome': [192, 193, 194],
#  'lawnmower man 2: beyond cyberspace': [195, 196, 197],
#  'two bits': [198, 199, 200],
#  'gazon maudit': [201, 202, 203],
#  'friday': [204, 205, 206],
#  'from dusk till dawn': [207, 208, 209],
#  'fair game': [210, 211, 212],
#  'kicking and screaming': [213, 214, 215],
#  'les misérables': [216, 217, 218],
#  'bed of roses': [219, 220, 221],
#  'big bully': [222, 223, 224],
#  'screamers': [225, 226, 227],
#  'nico icon': [228, 229, 230],
#  'the crossing guard': [231, 232, 233],
#  'the juror': [234, 235, 236],
#  'بادکنک سفید': [237, 238, 239],
#  "things to do in denver when you're dead": [240, 241, 242],
#  'antonia': [243, 244, 245],
#  'once upon a time... when we were colored': [246, 247, 248],
#  'last summer in the hamptons': [249, 250, 251],
#  'angels and insects': [252, 253, 254],
#  'white squall': [255, 256, 257],
#  'dunston checks in': [258, 259, 260],
#  'black sheep': [261, 262, 263],
#  'nick of time': [264, 265, 266],
#  'the journey of august king': [267, 268, 269],
#  'mary reilly': [270, 271, 272],
#  'vampire in brooklyn': [273, 274, 275],
#  'beautiful girls': [276, 277, 278],
#  'broken arrow': [279, 280, 281],
#  "a midwinter's tale": [282, 283, 284],
#  'la haine': [285, 286, 287],
#  'shopping': [288, 289, 290],
#  'heidi fleiss: hollywood madam': [291, 292, 293],
#  'city hall': [294, 295, 296],
#  'bottle rocket': [297, 298, 299],
#  'mr. wrong': [300, 301, 302],
#  'unforgettable': [303, 304, 305],
#  'happy gilmore': [306, 307, 308],
#  'the bridges of madison county': [309, 310, 311],
#  'keiner liebt mich': [312, 313, 314],
#  'muppet treasure island': [315, 316, 317],
#  'catwalk': [318, 319, 320],
#  'headless body in topless bar': [321, 322, 323],
#  'braveheart': [324, 325, 326],
#  'taxi driver': [327, 328, 329],
#  '紅番區': [330, 331, 332],
#  'before and after': [333, 334, 335],
#  "margaret's museum": [336, 337, 338],
#  'le bonheur est dans le pré': [339, 340, 341],
#  'anne frank remembered': [342, 343, 344],
#  "the young poisoner's handbook": [345, 346, 347],
#  'if lucy fell': [348, 349, 350],
#  'steal big steal little': [351, 352, 353],
#  'race the sun': [354, 355, 356],
#  'the boys of st. vincent': [357, 358, 359],
#  'boomerang': [360, 361, 362],
#  '重慶森林': [363, 364, 365],
#  "l'uomo delle stelle": [366, 367, 368],
#  'flirting with disaster': [369, 370, 371],
#  'the neverending story iii': [372, 373, 374],
#  'صمت القصور': [375, 376, 377],
#  "jupiter's wife": [378, 379, 380],
#  'pie in the sky': [381, 382, 383],
#  'angela': [384, 385, 386],
#  'frankie starlight': [387, 388, 389],
#  'jade': [390, 391, 392],
#  'nueba yol': [393, 394, 395],
#  'sonic outlaws': [396, 397, 398],
#  'down periscope': [399, 400, 401],
#  'from the journals of jean seberg': [402, 403, 404],
#  'man of the year': [405, 406, 407],
#  'the neon bible': [408, 409, 410],
#  'target': [411, 412, 413],
#  'up close & personal': [414, 415, 416],
#  'the birdcage': [417, 418, 419],
#  'gospa': [420, 421, 422],
#  'the brothers mcmullen': [423, 424, 425],
#  'bad boys': [426, 427, 428],
#  'the amazing panda adventure': [429, 430, 431],
#  'the basketball diaries': [432, 433, 434],
#  'an awfully big adventure': [435, 436, 437],
#  'amateur': [438, 439, 440],
#  'apollo 13': [441, 442, 443],
#  'rob roy': [444, 445, 446],
#  'the addiction': [447, 448, 449],
#  'batman forever': [450, 451, 452],
#  'belle de jour': [453, 454, 455],
#  'beyond rangoon': [456, 457, 458],
#  'blue in the face': [459, 460, 461],
#  'canadian bacon': [462, 463, 464],
#  'casper': [465, 466, 467],
#  'clockers': [468, 469, 470],
#  'congo': [471, 472, 473],
#  'crimson tide': [474, 475, 476],
#  'crumb': [477, 478, 479],
#  'desperado': [480, 481, 482],
#  'devil in a blue dress': [483, 484, 485],
#  'die hard: with a vengeance': [486, 487, 488],
#  'the doom generation': [489, 490, 491],
#  'feast of july': [492, 493, 494],
#  'first knight': [495, 496, 497],
#  'free willy 2 - the adventure home': [498, 499, 500],
#  'hackers': [501, 502, 503],
#  'jeffrey': [504, 505, 506],
#  'johnny mnemonic': [507, 508, 509],
#  'judge dredd': [510, 511, 512],
#  'jury duty': [513, 514, 515],
#  'kids': [516, 517, 518],
#  'living in oblivion': [519, 520, 521],
#  'lord of illusions': [522, 523, 524],
#  'love & human remains': [525, 526, 527],
#  'mad love': [528, 529, 530],
#  'mallrats': [531, 532, 533],
#  'mighty morphin power rangers: the movie': [534, 535, 536],
#  'moonlight and valentino': [537, 538, 539],
#  'mute witness': [540, 541, 542],
#  'nadja': [543, 544, 545],
#  'the net': [546, 547, 548],
#  'nine months': [549, 550, 551],
#  'party girl': [552, 553, 554],
#  'the prophecy': [555, 556, 557],
#  'reckless': [558, 559, 560],
#  'safe': [561, 562, 563],
#  'the scarlet letter': [564, 565, 566],
#  'the show': [567, 568, 569],
#  'showgirls': [570, 571, 572],
#  'smoke': [573, 574, 575],
#  'something to talk about': [576, 577, 578],
#  'species': [579, 580, 581],
#  'the stars fell on henrietta': [582, 583, 584],
#  'strange days': [585, 586, 587],
#  'les parapluies de cherbourg': [588, 589, 590],
#  'the tie that binds': [591, 592, 593],
#  'three wishes': [594, 595, 596],
#  'total eclipse': [597, 598, 599],
#  'to wong foo, thanks for everything! julie newmar': [600, 601, 602],
#  'under siege 2: dark territory': [603, 604, 605],
#  'unstrung heroes': [606, 607, 608],
#  'unzipped': [609, 610, 611],
#  'a walk in the clouds': [612, 613, 614],
#  'waterworld': [615, 616, 617],
#  "white man's burden": [618, 619, 620],
#  'wild bill': [621, 622, 623],
#  'the browning version': [624, 625, 626],
#  'bushwhacked': [627, 628, 629],
#  'утомлённые солнцем': [630, 631, 632],
#  'before the rain': [633, 634, 635],
#  'before sunrise': [636, 637, 638],
#  'billy madison': [639, 640, 641],
#  'the babysitter': [642, 643, 644],
#  'boys on the side': [645, 646, 647],
#  'the cure': [648, 649, 650],
#  'castle freak': [651, 652, 653],
#  'circle of friends': [654, 655, 656],
#  'clerks': [657, 658, 659],
#  'don juan demarco': [660, 661, 662],
#  'disclosure': [663, 664, 665],
#  'dream man': [666, 667, 668],
#  'drop zone': [669, 670, 671],
#  'destiny turns on the radio': [672, 673, 674],
#  'death and the maiden': [675, 676, 677],
#  'dolores claiborne': [678, 679, 680],
#  'dumb and dumber': [681, 682, 683],
#  '飲食男女': [684, 685, 686],
#  'exotica': [687, 688, 689],
#  'exit to eden': [690, 691, 692],
#  'ed wood': [693, 694, 695],
#  'french kiss': [696, 697, 698],
#  'forget paris': [699, 700, 701],
#  'far from home: the adventures of yellow dog': [702, 703, 704],
#  'a goofy movie': [705, 706, 707],
#  'hideaway': [708, 709, 710],
#  'fluke': [711, 712, 713],
#  'farinelli': [714, 715, 716],
#  'gordy': [717, 718, 719],
#  'gumby: the movie': [720, 721, 722],
#  'the glass shield': [723, 724, 725],
#  'hoop dreams': [726, 727, 728],
#  'heavenly creatures': [729, 730, 731],
#  'houseguest': [732, 733, 734],
#  'immortal beloved': [735, 736, 737],
#  'heavyweights': [738, 739, 740],
#  'the hunted': [741, 742, 743],
#  'i.q.': [744, 745, 746],
#  'interview with the vampire': [747, 748, 749],
#  'jefferson in paris': [750, 751, 752],
#  'the jerky boys': [753, 754, 755],
#  'junior': [756, 757, 758],
#  'just cause': [759, 760, 761],
#  "a kid in king arthur's court": [762, 763, 764],
#  'kiss of death': [765, 766, 767],
#  'star wars': [768, 769, 770],
#  'little women': [771, 772, 773],
#  'a little princess': [774, 775, 776],
#  'ladybird ladybird': [777, 778, 779],
#  "l'enfer": [780, 781, 782],
#  'como agua para chocolate': [783, 784, 785],
#  'legends of the fall': [786, 787, 788],
#  'major payne': [789, 790, 791],
#  'little odessa': [792, 793, 794],
#  'mi vida loca': [795, 796, 797],
#  'love affair': [798, 799, 800],
#  'losing isaiah': [801, 802, 803],
#  'the madness of king george': [804, 805, 806],
#  'frankenstein': [807, 808, 809],
#  'man of the house': [810, 811, 812],
#  'mixed nuts': [813, 814, 815],
#  'milk money': [816, 817, 818],
#  'miracle on 34th street': [819, 820, 821],
#  'miami rhapsody': [822, 823, 824],
#  'my family': [825, 826, 827],
#  'murder in the first': [828, 829, 830],
#  "nobody's fool": [831, 832, 833],
#  'nell': [834, 835, 836],
#  'new jersey drive': [837, 838, 839],
#  'new york cop': [840, 841, 842],
#  'beyond bedlam': [843, 844, 845],
#  'nemesis 2 - nebula': [846, 847, 848],
#  'nina takes a lover': [849, 850, 851],
#  'natural born killers': [852, 853, 854],
#  'only you': [855, 856, 857],
#  'once were warriors': [858, 859, 860],
#  'poison ivy ii: lily': [861, 862, 863],
#  'outbreak': [864, 865, 866],
#  'léon': [867, 868, 869],
#  'the perez family': [870, 871, 872],
#  "a pyromaniac's love story": [873, 874, 875],
#  'pulp fiction': [876, 877, 878],
#  'panther': [879, 880, 881],
#  'pushing hands': [882, 883, 884],
#  'priest': [885, 886, 887],
#  'quiz show': [888, 889, 890],
#  'picture bride': [891, 892, 893],
#  'la reine margot': [894, 895, 896],
#  'the quick and the dead': [897, 898, 899],
#  'roommates': [900, 901, 902],
#  'prêt-à-porter': [903, 904, 905],
#  'trois couleurs : rouge': [906, 907, 908],
#  'trois couleurs : bleu': [909, 910, 911],
#  'trois couleurs : blanc': [912, 913, 914],
#  'pao da shuang deng': [915, 916, 917],
#  'rent-a-kid': [918, 919, 920],
#  'relative fear': [921, 922, 923],
#  'stuart saves his family': [924, 925, 926],
#  'the swan princess': [927, 928, 929],
#  'the secret of roan inish': [930, 931, 932],
#  'the specialist': [933, 934, 935],
#  'stargate': [936, 937, 938],
#  'the santa clause': [939, 940, 941],
#  'the shawshank redemption': [942, 943, 944],
#  'shallow grave': [945, 946, 947],
#  'suture': [948, 949, 950],
#  'fresa y chocolate': [951, 952, 953],
#  'swimming with sharks': [954, 955, 956],
#  'the sum of us': [957, 958, 959],
#  'senior trip': [960, 961, 962],
#  '活着': [963, 964, 965],
#  'tank girl': [966, 967, 968],
#  'tales from the crypt: demon knight': [969, 970, 971],
#  'star trek: generations': [972, 973, 974],
#  'tales from the hood': [975, 976, 977],
#  'tom & viv': [978, 979, 980],
#  'village of the damned': [981, 982, 983],
#  'tommy boy': [984, 985, 986],
#  'vanya on 42nd street': [987, 988, 989],
#  'the underneath': [990, 991, 992],
#  'the walking dead': [993, 994, 995],
#  "what's eating gilbert grape": [996, 997, 998],
#  'virtuosity': [999, 1000, 1001],
#  'while you were sleeping': [1002, 1003, 1004],
#  'the war': [1005, 1006, 1007],
#  'double happiness': [1008, 1009, 1010],
#  "muriel's wedding": [1011, 1012, 1013],
#  'the baby-sitters club': [1014, 1015, 1016],
#  'ace ventura: pet detective': [1017, 1018, 1019],
#  'the adventures of priscilla, queen of the desert': [1020, 1021, 1022],
#  'backbeat': [1023, 1024, 1025],
#  'bitter moon': [1026, 1027, 1028],
#  'bullets over broadway': [1029, 1030, 1031],
#  'clear and present danger': [1032, 1033, 1034],
#  'the client': [1035, 1036, 1037],
#  'corrina, corrina': [1038, 1039, 1040],
#  'crooklyn': [1041, 1042, 1043],
#  'the crow': [1044, 1045, 1046],
#  'cobb': [1047, 1048, 1049],
#  'the flintstones': [1050, 1051, 1052],
#  'forrest gump': [1053, 1054, 1055],
#  'four weddings and a funeral': [1056, 1057, 1058],
#  'higher learning': [1059, 1060, 1061],
#  'i like it like that': [1062, 1063, 1064],
#  'i love trouble': [1065, 1066, 1067],
#  'it could happen to you': [1068, 1069, 1070],
#  'the jungle book': [1071, 1072, 1073],
#  'die macht der bilder: leni riefenstahl': [1074, 1075, 1076],
#  'the lion king': [1077, 1078, 1079],
#  'little buddha': [1080, 1081, 1082],
#  'new nightmare': [1083, 1084, 1085],
#  'the mask': [1086, 1087, 1088],
#  'maverick': [1089, 1090, 1091],
#  'mrs. parker and the vicious circle': [1092, 1093, 1094],
#  'the naked gun 33⅓: the final insult': [1095, 1096, 1097],
#  'the paper': [1098, 1099, 1100],
#  'reality bites': [1101, 1102, 1103],
#  'red rock west': [1104, 1105, 1106],
#  'ri¢hie ri¢h': [1107, 1108, 1109],
#  'safe passage': [1110, 1111, 1112],
#  'the river wild': [1113, 1114, 1115],
#  'speed': [1116, 1117, 1118],
#  'speechless': [1119, 1120, 1121],
#  'timecop': [1122, 1123, 1124],
#  'true lies': [1125, 1126, 1127],
#  'when a man loves a woman': [1128, 1129, 1130],
#  'wolf': [1131, 1132, 1133],
#  'wyatt earp': [1134, 1135, 1136],
#  'bad company': [1137, 1138, 1139],
#  'a man of no importance': [1140, 1141, 1142],
#  's.f.w.': [1143, 1144, 1145],
#  'a low down dirty shame': [1146, 1147, 1148],
#  'boys life: three stories of love, lust, and liberation': [1149, 1150, 1151],
#  'le colonel chabert': [1152, 1153, 1154],
#  'faster, pussycat! kill! kill!': [1155, 1156, 1157],
#  "jason's lyric": [1158, 1159, 1160],
#  'the secret adventures of tom thumb': [1161, 1162, 1163],
#  'street fighter': [1164, 1165, 1166],
#  'coldblooded': [1167, 1168, 1169],
#  'desert winds': [1170, 1171, 1172],
#  'fall time': [1173, 1174, 1175],
#  'the fear': [1176, 1177, 1178],
#  'frank and ollie': [1179, 1180, 1181],
#  'girl in the cadillac': [1182, 1183, 1184],
#  'homage': [1185, 1186, 1187],
#  'mirage': [1188, 1189, 1190],
#  'open season': [1191, 1192, 1193],
#  'dos crímenes': [1194, 1195, 1196],
#  'brother minister: the assassination of malcolm x': [1197, 1198, 1199],
#  'highlander iii: the sorcerer': [1200, 1201, 1202],
#  'federal hill': [1203, 1204, 1205],
#  'in the mouth of madness': [1206, 1207, 1208],
#  '8 seconds': [1209, 1210, 1211],
#  'above the rim': [1212, 1213, 1214],
#  'addams family values': [1215, 1216, 1217],
#  'martin lawrence: you so crazy': [1218, 1219, 1220],
#  'the age of innocence': [1221, 1222, 1223],
#  'airheads': [1224, 1225, 1226],
#  'the air up there': [1227, 1228, 1229],
#  'another stakeout': [1230, 1231, 1232],
#  'bad girls': [1233, 1234, 1235],
#  'barcelona': [1236, 1237, 1238],
#  'being human': [1239, 1240, 1241],
#  'the beverly hillbillies': [1242, 1243, 1244],
#  'beverly hills cop iii': [1245, 1246, 1247],
#  'black beauty': [1248, 1249, 1250],
#  'blink': [1251, 1252, 1253],
#  'blown away': [1254, 1255, 1256],
#  'blue chips': [1257, 1258, 1259],
#  'blue sky': [1260, 1261, 1262],
#  'body snatchers': [1263, 1264, 1265],
#  'boxing helena': [1266, 1267, 1268],
#  'a bronx tale': [1269, 1270, 1271],
#  'cabin boy': [1272, 1273, 1274],
#  'calendar girl': [1275, 1276, 1277],
#  "carlito's way": [1278, 1279, 1280],
#  "city slickers ii: the legend of curly's gold": [1281, 1282, 1283],
#  'clean slate': [1284, 1285, 1286],
#  'cliffhanger': [1287, 1288, 1289],
#  'coneheads': [1290, 1291, 1292],
#  'color of night': [1293, 1294, 1295],
#  'cops & robbersons': [1296, 1297, 1298],
#  'the cowboy way': [1299, 1300, 1301],
#  'dangerous game': [1302, 1303, 1304],
#  'dave': [1305, 1306, 1307],
#  'dazed and confused': [1308, 1309, 1310],
#  'demolition man': [1311, 1312, 1313],
#  'the endless summer 2': [1314, 1315, 1316],
#  'even cowgirls get the blues': [1317, 1318, 1319],
#  'fatal instinct': [1320, 1321, 1322],
#  '霸王别姬': [1323, 1324, 1325],
#  'the favor': [1326, 1327, 1328],
#  'fearless': [1329, 1330, 1331],
#  'fear of a black hat': [1332, 1333, 1334],
#  'with honors': [1335, 1336, 1337],
#  'flesh and bone': [1338, 1339, 1340],
#  "widows' peak": [1341, 1342, 1343],
#  'for love or money': [1344, 1345, 1346],
#  'the firm': [1347, 1348, 1349],
#  'free willy': [1350, 1351, 1352],
#  'fresh': [1353, 1354, 1355],
#  'the fugitive': [1356, 1357, 1358],
#  'geronimo: an american legend': [1359, 1360, 1361],
#  'the getaway': [1362, 1363, 1364],
#  'getting even with dad': [1365, 1366, 1367],
#  'go fish': [1368, 1369, 1370],
#  'a good man in africa': [1371, 1372, 1373],
#  'guilty as sin': [1374, 1375, 1376],
#  'hard target': [1377, 1378, 1379],
#  'heaven & earth': [1380, 1381, 1382],
#  'hot shots! part deux': [1383, 1384, 1385],
#  'live nude girls': [1386, 1387, 1388],
#  'the englishman who went up a hill but came down a mountain': [1389,
#   1390,
#   1391],
#  'the house of the spirits': [1392, 1393, 1394],
#  'house party 3': [1395, 1396, 1397],
#  'the hudsucker proxy': [1398, 1399, 1400],
#  "i'll do anything": [1401, 1402, 1403],
#  'in the army now': [1404, 1405, 1406],
#  'in the line of fire': [1407, 1408, 1409],
#  'in the name of the father': [1410, 1411, 1412],
#  'the inkwell': [1413, 1414, 1415],
#  "what's love got to do with it": [1416, 1417, 1418],
#  'jimmy hollywood': [1419, 1420, 1421],
#  'judgment night': [1422, 1423, 1424],
#  'jurassic park': [1425, 1426, 1427],
#  'kalifornia': [1428, 1429, 1430],
#  'killing zoe': [1431, 1432, 1433],
#  'king of the hill': [1434, 1435, 1436],
#  'lassie': [1437, 1438, 1439],
#  'last action hero': [1440, 1441, 1442],
#  'life with mikey': [1443, 1444, 1445],
#  'lightning jack': [1446, 1447, 1448],
#  'm. butterfly': [1449, 1450, 1451],
#  'made in america': [1452, 1453, 1454],
#  'malice': [1455, 1456, 1457],
#  'the man without a face': [1458, 1459, 1460],
#  'manhattan murder mystery': [1461, 1462, 1463],
#  'menace ii society': [1464, 1465, 1466],
#  'executive decision': [1467, 1468, 1469],
#  '愛のコリーダ': [1470, 1471, 1472],
#  'what happened was...': [1473, 1474, 1475],
#  'much ado about nothing': [1476, 1477, 1478],
#  'mr. jones': [1479, 1480, 1481],
#  'mr. wonderful': [1482, 1483, 1484],
#  'mrs. doubtfire': [1485, 1486, 1487],
#  'naked': [1488, 1489, 1490],
#  'the next karate kid': [1491, 1492, 1493],
#  'the new age': [1494, 1495, 1496],
#  'no escape': [1497, 1498, 1499],
#  'north': [1500, 1501, 1502],
#  'orlando': [1503, 1504, 1505],
#  'a perfect world': [1506, 1507, 1508],
#  'philadelphia': [1509, 1510, 1511],
#  'the piano': [1512, 1513, 1514],
#  'poetic justice': [1515, 1516, 1517],
#  'the program': [1518, 1519, 1520],
#  'the puppet masters': [1521, 1522, 1523],
#  'radioland murders': [1524, 1525, 1526],
#  'the ref': [1527, 1528, 1529],
#  'the remains of the day': [1530, 1531, 1532],
#  'renaissance man': [1533, 1534, 1535],
#  'rising sun': [1536, 1537, 1538],
#  'the road to wellville': [1539, 1540, 1541],
#  'robocop 3': [1542, 1543, 1544],
#  'robin hood: men in tights': [1545, 1546, 1547],
#  'romeo is bleeding': [1548, 1549, 1550],
#  'romper stomper': [1551, 1552, 1553],
#  'ruby in paradise': [1554, 1555, 1556],
#  'rudy': [1557, 1558, 1559],
#  'the saint of fort washington': [1560, 1561, 1562],
#  'les nuits fauves': [1563, 1564, 1565],
#  "schindler's list": [1566, 1567, 1568],
#  'the scout': [1569, 1570, 1571],
#  'searching for bobby fischer': [1572, 1573, 1574],
#  'second best': [1575, 1576, 1577],
#  'the secret garden': [1578, 1579, 1580],
#  'serial mom': [1581, 1582, 1583],
#  'the shadow': [1584, 1585, 1586],
#  'shadowlands': [1587, 1588, 1589],
#  'short cuts': [1590, 1591, 1592],
#  'a simple twist of fate': [1593, 1594, 1595],
#  'sirens': [1596, 1597, 1598],
#  'six degrees of separation': [1599, 1600, 1601],
#  'sleepless in seattle': [1602, 1603, 1604],
#  'sliver': [1605, 1606, 1607],
#  'blade runner': [1608, 1609, 1610],
#  'son in law': [1611, 1612, 1613],
#  'so i married an axe murderer': [1614, 1615, 1616],
#  'striking distance': [1617, 1618, 1619],
#  'harem': [1620, 1621, 1622],
#  'super mario bros.': [1623, 1624, 1625],
#  'surviving the game': [1626, 1627, 1628],
#  'terminal velocity': [1629, 1630, 1631],
#  'thirty two short films about glenn gould': [1632, 1633, 1634],
#  'threesome': [1635, 1636, 1637],
#  'the nightmare before christmas': [1638, 1639, 1640],
#  'the three musketeers': [1641, 1642, 1643],
#  'tombstone': [1644, 1645, 1646],
#  'trial by jury': [1647, 1648, 1649],
#  'true romance': [1650, 1651, 1652],
#  'the war room': [1653, 1654, 1655],
#  'the pagemaster': [1656, 1657, 1658],
#  'paris, france': [1659, 1660, 1661],
#  'the beans of egypt, maine': [1662, 1663, 1664],
#  'killer': [1665, 1666, 1667],
#  'welcome to the dollhouse': [1668, 1669, 1670],
#  'germinal': [1671, 1672, 1673],
#  'chasers': [1674, 1675, 1676],
#  'cronos': [1677, 1678, 1679],
#  'naked in new york': [1680, 1681, 1682],
#  'kika': [1683, 1684, 1685],
#  'bhaji on the beach': [1686, 1687, 1688],
#  'little big league': [1689, 1690, 1691],
#  'kådisbellan': [1692, 1693, 1694],
#  'wide eyed and legless': [1695, 1696, 1697],
#  'foreign student': [1698, 1699, 1700],
#  'io speriamo che me la cavo': [1701, 1702, 1703],
#  'spanking the monkey': [1704, 1705, 1706],
#  'the little rascals': [1707, 1708, 1709],
#  'à la mode': [1710, 1711, 1712],
#  'andre': [1713, 1714, 1715],
#  'la scorta': [1716, 1717, 1718],
#  'princess caraboo': [1719, 1720, 1721],
#  'the celluloid closet': [1722, 1723, 1724],
#  'métisse': [1725, 1726, 1727],
#  'caro diario': [1728, 1729, 1730],
#  'de eso no se habla': [1731, 1732, 1733],
#  'the brady bunch movie': [1734, 1735, 1736],
#  'home alone': [1737, 1738, 1739],
#  'ghost': [1740, 1741, 1742],
#  'aladdin': [1743, 1744, 1745],
#  'terminator 2: judgment day': [1746, 1747, 1748],
#  'dances with wolves': [1749, 1750, 1751],
#  'tough and deadly': [1752, 1753, 1754],
#  'batman': [1755, 1756, 1757],
#  'the silence of the lambs': [1758, 1759, 1760],
#  'snow white and the seven dwarfs': [1761, 1762, 1763],
#  'beauty and the beast': [1764, 1765, 1766],
#  'pinocchio': [1767, 1768, 1769],
#  'pretty woman': [1770, 1771, 1772],
#  'окно в париж': [1773, 1774, 1775],
#  'the wild bunch': [1776, 1777, 1778],
#  'love and a .45': [1779, 1780, 1781],
#  "the wooden man's bride": [1782, 1783, 1784],
#  'a great day in harlem': [1785, 1786, 1787],
#  'bye bye love': [1788, 1789, 1790],
#  'one fine day': [1791, 1792, 1793],
#  'candyman: farewell to the flesh': [1794, 1795, 1796],
#  'century': [1797, 1798, 1799],
#  'fargo': [1800, 1801, 1802],
#  'homeward bound ii: lost in san francisco': [1803, 1804, 1805],
#  'heavy metal': [1806, 1807, 1808],
#  'hellraiser: bloodline': [1809, 1810, 1811],
#  'the pallbearer': [1812, 1813, 1814],
#  'jane eyre': [1815, 1816, 1817],
#  'loaded': [1818, 1819, 1820],
#  'pane e cioccolata': [1821, 1822, 1823],
#  'the aristocats': [1824, 1825, 1826],
#  'la flor de mi secreto': [1827, 1828, 1829],
#  'two much': [1830, 1831, 1832],
#  'ed': [1833, 1834, 1835],
#  'schrei aus stein': [1836, 1837, 1838],
#  'ma saison préférée': [1839, 1840, 1841],
#  'a modern affair': [1842, 1843, 1844],
#  'condition red': [1845, 1846, 1847],
#  'asfour stah': [1848, 1849, 1850],
#  'a thin line between love and hate': [1851, 1852, 1853],
#  'the last supper': [1854, 1855, 1856],
#  'primal fear': [1857, 1858, 1859],
#  'rude': [1860, 1861, 1862],
#  'carried away': [1863, 1864, 1865],
#  'all dogs go to heaven 2': [1866, 1867, 1868],
#  'land and freedom': [1869, 1870, 1871],
#  'denise calls up': [1872, 1873, 1874],
#  'theodore rex': [1875, 1876, 1877],
#  'a family thing': [1878, 1879, 1880],
#  'frisk': [1881, 1882, 1883],
#  'sgt. bilko': [1884, 1885, 1886],
#  'jack & sarah': [1887, 1888, 1889],
#  'girl 6': [1890, 1891, 1892],
#  'diabolique': [1893, 1894, 1895],
#  'un indien dans la ville': [1896, 1897, 1898],
#  'roula - dunkle geheimnisse': [1899, 1900, 1901],
#  'peanuts – die bank zahlt alles': [1902, 1903, 1904],
#  'happy weekend': [1905, 1906, 1907],
#  'nelly & monsieur arnaud': [1908, 1909, 1910],
#  'courage under fire': [1911, 1912, 1913],
#  'mission: impossible': [1914, 1915, 1916],
#  'á köldum klaka': [1917, 1918, 1919],
#  'moll flanders': [1920, 1921, 1922],
#  'das superweib': [1923, 1924, 1925],
#  '삼공일 삼공이': [1926, 1927, 1928],
#  'dragonheart': [1929, 1930, 1931],
#  'und keiner weint mir nach': [1932, 1933, 1934],
#  "my mother's courage": [1935, 1936, 1937],
#  'eddie': [1938, 1939, 1940],
#  'yankee zulu': [1941, 1942, 1943],
#  "billy's holiday": [1944, 1945, 1946],
#  'plein soleil': [1947, 1948, 1949],
#  'august': [1950, 1951, 1952],
#  'james and the giant peach': [1953, 1954, 1955],
#  'fear': [1956, 1957, 1958],
#  'kids in the hall: brain candy': [1959, 1960, 1961],
#  'faithful': [1962, 1963, 1964],
#  'podzemlje': [1965, 1966, 1967],
#  'lust och fägring stor': [1968, 1969, 1970],
#  'bloodsport ii': [1971, 1972, 1973],
#  'পথের পাঁচালী': [1974, 1975, 1976],
#  'অপুর সংসার': [1977, 1978, 1979],
#  'mystery science theater 3000: the movie': [1980, 1981, 1982],
#  'tarantella': [1983, 1984, 1985],
#  'space jam': [1986, 1987, 1988],
#  'barbarella': [1989, 1990, 1991],
#  'hostile intentions': [1992, 1993, 1994],
#  'they bite': [1995, 1996, 1997],
#  'some folks call it a sling blade': [1998, 1999, 2000],
#  'the run of the country': [2001, 2002, 2003],
#  'alphaville, une étrange aventure de lemmy caution': [2004, 2005, 2006],
#  'coup de torchon': [2007, 2008, 2009],
#  'tigrero: a film that was never made': [2010, 2011, 2012],
#  "l'oeil de vichy": [2013, 2014, 2015],
#  'windows': [2016, 2017, 2018],
#  "it's my party": [2019, 2020, 2021],
#  'country life': [2022, 2023, 2024],
#  'operation dumbo drop': [2025, 2026, 2027],
#  'das versprechen': [2028, 2029, 2030],
#  'mrs. winterbourne': [2031, 2032, 2033],
#  'solo': [2034, 2035, 2036],
#  'etz hadomim tafus': [2037, 2038, 2039],
#  'the substitute': [2040, 2041, 2042],
#  'true crime': [2043, 2044, 2045],
#  'butterfly kiss': [2046, 2047, 2048],
#  'feeling minnesota': [2049, 2050, 2051],
#  'delta of venus': [2052, 2053, 2054],
#  'to cross the rubicon': [2055, 2056, 2057],
#  'angus': [2058, 2059, 2060],
#  'daens': [2061, 2062, 2063],
#  'faces': [2064, 2065, 2066],
#  'boys': [2067, 2068, 2069],
#  'the quest': [2070, 2071, 2072],
#  'cosi': [2073, 2074, 2075],
#  'sunset park': [2076, 2077, 2078],
#  'mulholland falls': [2079, 2080, 2081],
#  'the truth about cats & dogs': [2082, 2083, 2084],
#  'oliver & company': [2085, 2086, 2087],
#  'celtic pride': [2088, 2089, 2090],
#  'flipper': [2091, 2092, 2093],
#  'captives': [2094, 2095, 2096],
#  'of love and shadows': [2097, 2098, 2099],
#  'dead man': [2100, 2101, 2102],
#  'le hussard sur le toit': [2103, 2104, 2105],
#  'switchblade sisters': [2106, 2107, 2108],
#  'boca a boca': [2109, 2110, 2111],
#  'les visiteurs': [2112, 2113, 2114],
#  'multiplicity': [2115, 2116, 2117],
#  'the haunted world of edward d. wood, jr.': [2118, 2119, 2120],
#  'due amici': [2121, 2122, 2123],
#  'the craft': [2124, 2125, 2126],
#  'the great white hype': [2127, 2128, 2129],
#  'last dance': [2130, 2131, 2132],
#  'war stories our mother never told us': [2133, 2134, 2135],
#  'cold comfort farm': [2136, 2137, 2138],
#  'institute benjamenta, or this dream people call human life': [2139,
#   2140,
#   2141],
#  "heaven's prisoners": [2142, 2143, 2144],
#  'original gangstas': [2145, 2146, 2147],
#  'the rock': [2148, 2149, 2150],
#  'getting away with murder': [2151, 2152, 2153],
#  'dellamorte dellamore': [2154, 2155, 2156],
#  'twister': [2157, 2158, 2159],
#  'barb wire': [2160, 2161, 2162],
#  'le garçu': [2163, 2164, 2165],
#  'honigmond': [2166, 2167, 2168],
#  'ghost in the shell': [2169, 2170, 2171],
#  'thinner': [2172, 2173, 2174],
#  'spy hard': [2175, 2176, 2177],
#  'brothers in trouble': [2178, 2179, 2180],
#  'a close shave': [2181, 2182, 2183],
#  'force of evil': [2184, 2185, 2186],
#  'the stupids': [2187, 2188, 2189],
#  'the arrival': [2190, 2191, 2192],
#  'the man from down under': [2193, 2194, 2195],
#  'dr. strangelove or: how i learned to stop worrying and love the bomb': [2196,
#   2197,
#   2198],
#  'careful': [2199, 2200, 2201],
#  'vermont is for lovers': [2202, 2203, 2204],
#  'a month by the lake': [2205, 2206, 2207],
#  'gold diggers: the secret of bear mountain': [2208, 2209, 2210],
#  'kim': [2211, 2212, 2213],
#  'carmen miranda: bananas is my business': [2214, 2215, 2216],
#  '東邪西毒': [2217, 2218, 2219],
#  'khomreh': [2220, 2221, 2222],
#  'maya lin: a strong clear vision': [2223, 2224, 2225],
#  'stalingrad': [2226, 2227, 2228],
#  'the phantom': [2229, 2230, 2231],
#  'striptease': [2232, 2233, 2234],
#  'the last of the high kings': [2235, 2236, 2237],
#  'heavy': [2238, 2239, 2240],
#  'jack': [2241, 2242, 2243],
#  'i shot andy warhol': [2244, 2245, 2246],
#  'the grass harp': [2247, 2248, 2249],
#  'tuđa amerika': [2250, 2251, 2252],
#  'la vie est belle': [2253, 2254, 2255],
#  'quartier mozart': [2256, 2257, 2258],
#  'touki-bouki': [2259, 2260, 2261],
#  'wend kuuni': [2262, 2263, 2264],
#  'histoires extraordinaires': [2265, 2266, 2267],
#  'babyfever': [2268, 2269, 2270],
#  "pharaoh's  army": [2271, 2272, 2273],
#  'trainspotting': [2274, 2275, 2276],
#  'til there was you': [2277, 2278, 2279],
#  'independence day': [2280, 2281, 2282],
#  'stealing beauty': [2283, 2284, 2285],
#  'the fan': [2286, 2287, 2288],
#  'the hunchback of notre dame': [2289, 2290, 2291],
#  'the cable guy': [2292, 2293, 2294],
#  'kingpin': [2295, 2296, 2297],
#  'eraser': [2298, 2299, 2300],
#  'the gate of heavenly peace': [2301, 2302, 2303],
#  'the nutty professor': [2304, 2305, 2306],
#  'yo, la peor de todas': [2307, 2308, 2309],
#  'un été inoubliable': [2310, 2311, 2312],
#  'hol volt, hol nem volt': [2313, 2314, 2315],
#  "en compagnie d'antonin artaud": [2316, 2317, 2318],
#  'sibak': [2319, 2320, 2321],
#  'somebody to love': [2322, 2323, 2324],
#  'a very natural thing': [2325, 2326, 2327],
#  'la vieille qui marchait dans la mer': [2328, 2329, 2330],
#  'daylight': [2331, 2332, 2333],
#  'the frighteners': [2334, 2335, 2336],
#  'lone star': [2337, 2338, 2339],
#  'harriet the spy': [2340, 2341, 2342],
#  'phenomenon': [2343, 2344, 2345],
#  'walking and talking': [2346, 2347, 2348],
#  "she's the one": [2349, 2350, 2351],
#  'a time to kill': [2352, 2353, 2354],
#  'american buffalo': [2355, 2356, 2357],
#  'les rendez-vous de paris': [2358, 2359, 2360],
#  'alaska': [2361, 2362, 2363],
#  'fled': [2364, 2365, 2366],
#  'kazaam': [2367, 2368, 2369],
#  'bűvös vadász': [2370, 2371, 2372],
#  'larger than life': [2373, 2374, 2375],
#  'a boy called hate': [2376, 2377, 2378],
#  'power 98': [2379, 2380, 2381],
#  'two deaths': [2382, 2383, 2384],
#  'a very brady sequel': [2385, 2386, 2387],
#  'stefano quantestorie': [2388, 2389, 2390],
#  'la mort en ce jardin': [2391, 2392, 2393],
#  'hedd wyn': [2394, 2395, 2396],
#  'la collectionneuse': [2397, 2398, 2399],
#  'kaspar hauser': [2400, 2401, 2402],
#  'echte kerle': [2403, 2404, 2405],
#  'diebinnen': [2406, 2407, 2408],
#  'o convento': [2409, 2410, 2411],
#  'the adventures of pinocchio': [2412, 2413, 2414],
#  "joe's apartment": [2415, 2416, 2417],
#  'the first wives club': [2418, 2419, 2420],
#  'stonewall': [2421, 2422, 2423],
#  'ransom': [2424, 2425, 2426],
#  'high school high': [2427, 2428, 2429],
#  'phat beach': [2430, 2431, 2432],
#  'foxfire': [2433, 2434, 2435],
#  'chain reaction': [2436, 2437, 2438],
#  'matilda': [2439, 2440, 2441],
#  'emma': [2442, 2443, 2444],
#  'the crow: city of angels': [2445, 2446, 2447],
#  'house arrest': [2448, 2449, 2450],
#  'les yeux sans visage': [2451, 2452, 2453],
#  'bordello of blood': [2454, 2455, 2456],
#  'lotto land': [2457, 2458, 2459],
#  'the story of xinghua': [2460, 2461, 2462],
#  '天國逆子': [2463, 2464, 2465],
#  'flirt': [2466, 2467, 2468],
#  'the big squeeze': [2469, 2470, 2471],
#  'the spitfire grill': [2472, 2473, 2474],
#  'escape from l.a.': [2475, 2476, 2477],
#  'xích lô': [2478, 2479, 2480],
#  'basquiat': [2481, 2482, 2483],
#  'tin cup': [2484, 2485, 2486],
#  'dingo': [2487, 2488, 2489],
#  '楢山節考': [2490, 2491, 2492],
#  'un week-end sur deux': [2493, 2494, 2495],
#  'mille bolle blu': [2496, 2497, 2498],
#  'wuya yu maque': [2499, 2500, 2501],
#  'the godfather': [2502, 2503, 2504],
#  'der bewegte mann': [2505, 2506, 2507],
#  '警察故事 iii：超級警察': [2508, 2509, 2510],
#  'manny & lo': [2511, 2512, 2513],
#  'tsuma': [2514, 2515, 2516],
#  'small faces': [2517, 2518, 2519],
#  'bound': [2520, 2521, 2522],
#  'carpool': [2523, 2524, 2525],
#  'death in brunswick': [2526, 2527, 2528],
#  'kansas city': [2529, 2530, 2531],
#  "gone fishin'": [2532, 2533, 2534],
#  "lover's knot": [2535, 2536, 2537],
#  '愛情萬歲': [2538, 2539, 2540],
#  'schatten der engel': [2541, 2542, 2543],
#  'killer: a journal of murder': [2544, 2545, 2546],
#  'nothing to lose': [2547, 2548, 2549],
#  '超级计划': [2550, 2551, 2552],
#  'girls town': [2553, 2554, 2555],
#  'bye-bye': [2556, 2557, 2558],
#  'the relic': [2559, 2560, 2561],
#  'the island of dr. moreau': [2562, 2563, 2564],
#  'first kid': [2565, 2566, 2567],
#  'the trigger effect': [2568, 2569, 2570],
#  'sweet nothing': [2571, 2572, 2573],
#  'bogus': [2574, 2575, 2576],
#  'bulletproof': [2577, 2578, 2579],
#  'talk of angels': [2580, 2581, 2582],
#  'the land before time iii: the time of the great giving': [2583, 2584, 2585],
#  '06': [2586, 2587, 2588],
#  'baton rouge': [2589, 2590, 2591],
#  'halloween: the curse of michael myers': [2592, 2593, 2594],
#  'twelfth night': [2595, 2596, 2597],
#  'mother night': [2598, 2599, 2600],
#  'liebelei': [2601, 2602, 2603],
#  'wenecja': [2604, 2605, 2606],
#  'les roseaux sauvages': [2607, 2608, 2609],
#  'for whom the bell tolls': [2610, 2611, 2612],
#  'the philadelphia story': [2613, 2614, 2615],
#  "singin' in the rain": [2616, 2617, 2618],
#  'an american in paris': [2619, 2620, 2621],
#  'funny face': [2622, 2623, 2624],
#  "breakfast at tiffany's": [2625, 2626, 2627],
#  'vertigo': [2628, 2629, 2630],
#  'rear window': [2631, 2632, 2633],
#  'it happened one night': [2634, 2635, 2636],
#  'gaslight': [2637, 2638, 2639],
#  'the gay divorcee': [2640, 2641, 2642],
#  'north by northwest': [2643, 2644, 2645],
#  'the apartment': [2646, 2647, 2648],
#  'some like it hot': [2649, 2650, 2651],
#  'charade': [2652, 2653, 2654],
#  'casablanca': [2655, 2656, 2657],
#  'the maltese falcon': [2658, 2659, 2660],
#  'my fair lady': [2661, 2662, 2663],
#  'roman holiday': [2664, 2665, 2666],
#  'the little princess': [2667, 2668, 2669],
#  'meet me in st. louis': [2670, 2671, 2672],
#  'the wizard of oz': [2673, 2674, 2675],
#  'gone with the wind': [2676, 2677, 2678],
#  'my favorite year': [2679, 2680, 2681],
#  'sunset boulevard': [2682, 2683, 2684],
#  'citizen kane': [2685, 2686, 2687],
#  '2001: a space odyssey': [2688, 2689, 2690],
#  'golden earrings': [2691, 2692, 2693],
#  'all about eve': [2694, 2695, 2696],
#  'the women': [2697, 2698, 2699],
#  'rebecca': [2700, 2701, 2702],
#  'foreign correspondent': [2703, 2704, 2705],
#  'notorious': [2706, 2707, 2708],
#  'spellbound': [2709, 2710, 2711],
#  'an affair to remember': [2712, 2713, 2714],
#  'to catch a thief': [2715, 2716, 2717],
#  'father of the bride': [2718, 2719, 2720],
#  'the band wagon': [2721, 2722, 2723],
#  'ninotchka': [2724, 2725, 2726],
#  'love in the afternoon': [2727, 2728, 2729],
#  'gigi': [2730, 2731, 2732],
#  'the reluctant debutante': [2733, 2734, 2735],
#  'the adventures of robin hood': [2736, 2737, 2738],
#  'the mark of zorro': [2739, 2740, 2741],
#  'laura': [2742, 2743, 2744],
#  'the ghost and mrs. muir': [2745, 2746, 2747],
#  'lost horizon': [2748, 2749, 2750],
#  'top hat': [2751, 2752, 2753],
#  'to be or not to be': [2754, 2755, 2756],
#  'my man godfrey': [2757, 2758, 2759],
#  'giant': [2760, 2761, 2762],
#  'east of eden': [2763, 2764, 2765],
#  'the thin man': [2766, 2767, 2768],
#  'his girl friday': [2769, 2770, 2771],
#  'around the world in eighty days': [2772, 2773, 2774],
#  "it's a wonderful life": [2775, 2776, 2777],
#  'mr. smith goes to washington': [2778, 2779, 2780],
#  'bringing up baby': [2781, 2782, 2783],
#  'penny serenade': [2784, 2785, 2786],
#  'lady of burlesque': [2787, 2788, 2789],
#  'of human bondage': [2790, 2791, 2792],
#  'angel on my shoulder': [2793, 2794, 2795],
#  'little lord fauntleroy': [2796, 2797, 2798],
#  'they made me a criminal': [2799, 2800, 2801],
#  'the inspector general': [2802, 2803, 2804],
#  'angel and the badman': [2805, 2806, 2807],
#  'the 39 steps': [2808, 2809, 2810],
#  'a walk in the sun': [2811, 2812, 2813],
#  'the outlaw': [2814, 2815, 2816],
#  'night of the living dead': [2817, 2818, 2819],
#  'the african queen': [2820, 2821, 2822],
#  'beat the devil': [2823, 2824, 2825],
#  'cat on a hot tin roof': [2826, 2827, 2828],
#  'the last time i saw paris': [2829, 2830, 2831],
#  'meet john doe': [2832, 2833, 2834],
#  'algiers': [2835, 2836, 2837],
#  'something to sing about': [2838, 2839, 2840],
#  'a farewell to arms': [2841, 2842, 2843],
#  'moonlight murder': [2844, 2845, 2846],
#  'nothing personal': [2847, 2848, 2849],
#  'huang jia shi jie': [2850, 2851, 2852],
#  'dangerous ground': [2853, 2854, 2855],
#  'picnic': [2856, 2857, 2858],
#  'madagascar skin': [2859, 2860, 2861],
#  'the pompatus of love': [2862, 2863, 2864],
#  'small wonders': [2865, 2866, 2867],
#  'fly away home': [2868, 2869, 2870],
#  'bliss': [2871, 2872, 2873],
#  'grace of my heart': [2874, 2875, 2876],
#  'schlafes bruder': [2877, 2878, 2879],
#  'maximum risk': [2880, 2881, 2882],
#  'michael collins': [2883, 2884, 2885],
#  "the rich man's wife": [2886, 2887, 2888],
#  'infinity': [2889, 2890, 2891],
#  'big night': [2892, 2893, 2894],
#  'last man standing': [2895, 2896, 2897],
#  'caught': [2898, 2899, 2900],
#  'set it off': [2901, 2902, 2903],
#  '2 days in the valley': [2904, 2905, 2906],
#  'curdled': [2907, 2908, 2909],
#  "l'associé": [2910, 2911, 2912],
#  "ed's next move": [2913, 2914, 2915],
#  'extreme measures': [2916, 2917, 2918],
#  'the glimmer man': [2919, 2920, 2921],
#  'd3: the mighty ducks': [2922, 2923, 2924],
#  'the chamber': [2925, 2926, 2927],
#  'the apple dumpling gang': [2928, 2929, 2930],
#  'davy crockett, king of the wild frontier': [2931, 2932, 2933],
#  'escape to witch mountain': [2934, 2935, 2936],
#  'the love bug': [2937, 2938, 2939],
#  'herbie rides again': [2940, 2941, 2942],
#  'old yeller': [2943, 2944, 2945],
#  'the parent trap': [2946, 2947, 2948],
#  'pollyanna': [2949, 2950, 2951],
#  'homeward bound: the incredible journey': [2952, 2953, 2954],
#  'the shaggy dog': [2955, 2956, 2957],
#  'swiss family robinson': [2958, 2959, 2960],
#  'that darn cat!': [2961, 2962, 2963],
#  '20,000 leagues under the sea': [2964, 2965, 2966],
#  'cool runnings': [2967, 2968, 2969],
#  'angels in the outfield': [2970, 2971, 2972],
#  'cinderella': [2973, 2974, 2975],
#  'winnie the pooh and the blustery day': [2976, 2977, 2978],
#  'the three caballeros': [2979, 2980, 2981],
#  'the sword in the stone': [2982, 2983, 2984],
#  'so dear to my heart': [2985, 2986, 2987],
#  'robin hood: prince of thieves': [2988, 2989, 2990],
#  'mary poppins': [2991, 2992, 2993],
#  'dumbo': [2994, 2995, 2996],
#  "pete's dragon": [2997, 2998, 2999],
#  ...}

# %%
# preprocess by removing non-character data, stopwords
cols = ['overview', 'original_title','tagline']

sample['combined'] = sample[cols].values.tolist()
tags_corpus = np.concatenate(sample['combined'].values.tolist())
# tags_corpus = sample['overview'].values
tags_corpus = [re.sub('-[!/()0-9]', '', x) for x in tags_corpus]
stop_words = stopwords.words('english')

tags_doc = [word_tokenize_clean(description, stop_words) for description in tags_corpus]
tags_doc[:1]
# Out:
# [['separate',
#   'eventually',
#   'happily',
#   'scene',
#   'aside',
#   'lightyear',
#   'losing',
#   'woody',
#   'plots',
#   'andy',
#   'duo',
#   'circumstances',
#   'birthday',
#   'owner',
#   'room',
#   'toys',
#   'live',
#   'put',
#   'learns',
#   'differences',
#   'led',
#   'buzz',
#   'place',
#   'afraid',
#   'heart',
#   'onto',
#   'brings']]

# %%
# prepare data as model input for Word2Vec
## it takes some time to execute
tags_doc = [TaggedDocument(words = word_tokenize_clean(D, stop_words), tags = [str(i)]) for i, D in enumerate(tags_corpus)]

# %%
# let's check what do we have
## tag = movie index
tags_doc[-1]
# Out:
# TaggedDocument(words=['queerama'], tags=['136397'])

# %% [markdown]
# # 2.2. Model Training and Evaluation

# %%
VEC_SIZE = 50
ALPHA = .02
MIN_ALPHA = .00025
MIN_COUNT = 5
EPOCHS = 20

# %%
# initialize
model = Doc2Vec(vector_size = VEC_SIZE,
                alpha = ALPHA, 
                min_alpha = MIN_ALPHA,
                min_count = MIN_COUNT,
                dm = 0)

# %%
# generate vocab from all tag docs
model.build_vocab(tags_doc)

# %%
# train model
model.train(tags_doc,
            total_examples = 45466,
            epochs = EPOCHS)

# %% [markdown]
# ## 2.3. Evaluate the model

# %% [markdown]
# Let's assume that we watched movie `batman` and based on that generate recommendation similar to it's description.
#
# To do that we need
# - To extract movie id from `movies_inv_mapper` we created to map back titles from model output
# - Load embeddings from trained model
# - Use built-in most_similar() method to get most relevant recommendations based on film embedding
# - Finally, map title names for sense-check

# %%
# get id
movie_id = movies_inv_mapper_up.get('batman')
movie_id = movie_id[1]
movie_id
# Out:
# 1756

# %%
# load trained embeddings 
movies_vectors = model.dv.vectors

# %%
movie_embeddings = movies_vectors[movie_id]

# %%
# get recommendations
similars = model.docvecs.most_similar(positive = [movie_embeddings], topn = 20)
output = pd.DataFrame(similars, columns = ['model_index', 'model_score'])
output.head()
# Out:
#   model_index  model_score
# 0        1756     1.000000
# 1      113215     0.974853
# 2       32779     0.974840
# 3       81125     0.974784
# 4       29341     0.974576

# %%
# reverse values and indices to map names in dataframe
k = 0
name_mapper = {}
# name_mapper = {v: k for k, v in movies_inv_mapper_up.items()}
for i in movies_inv_mapper_up:
    name_mapper[k] = i
    k=k+1
    name_mapper[k] = i
    k=k+1
    name_mapper[k] = i
    k=k+1
name_mapper
# Out:
# {0: 'toy story',
#  1: 'toy story',
#  2: 'toy story',
#  3: 'jumanji',
#  4: 'jumanji',
#  5: 'jumanji',
#  6: 'grumpier old men',
#  7: 'grumpier old men',
#  8: 'grumpier old men',
#  9: 'waiting to exhale',
#  10: 'waiting to exhale',
#  11: 'waiting to exhale',
#  12: 'father of the bride part ii',
#  13: 'father of the bride part ii',
#  14: 'father of the bride part ii',
#  15: 'heat',
#  16: 'heat',
#  17: 'heat',
#  18: 'sabrina',
#  19: 'sabrina',
#  20: 'sabrina',
#  21: 'tom and huck',
#  22: 'tom and huck',
#  23: 'tom and huck',
#  24: 'sudden death',
#  25: 'sudden death',
#  26: 'sudden death',
#  27: 'goldeneye',
#  28: 'goldeneye',
#  29: 'goldeneye',
#  30: 'the american president',
#  31: 'the american president',
#  32: 'the american president',
#  33: 'dracula: dead and loving it',
#  34: 'dracula: dead and loving it',
#  35: 'dracula: dead and loving it',
#  36: 'balto',
#  37: 'balto',
#  38: 'balto',
#  39: 'nixon',
#  40: 'nixon',
#  41: 'nixon',
#  42: 'cutthroat island',
#  43: 'cutthroat island',
#  44: 'cutthroat island',
#  45: 'casino',
#  46: 'casino',
#  47: 'casino',
#  48: 'sense and sensibility',
#  49: 'sense and sensibility',
#  50: 'sense and sensibility',
#  51: 'four rooms',
#  52: 'four rooms',
#  53: 'four rooms',
#  54: 'ace ventura: when nature calls',
#  55: 'ace ventura: when nature calls',
#  56: 'ace ventura: when nature calls',
#  57: 'money train',
#  58: 'money train',
#  59: 'money train',
#  60: 'get shorty',
#  61: 'get shorty',
#  62: 'get shorty',
#  63: 'copycat',
#  64: 'copycat',
#  65: 'copycat',
#  66: 'assassins',
#  67: 'assassins',
#  68: 'assassins',
#  69: 'powder',
#  70: 'powder',
#  71: 'powder',
#  72: 'leaving las vegas',
#  73: 'leaving las vegas',
#  74: 'leaving las vegas',
#  75: 'othello',
#  76: 'othello',
#  77: 'othello',
#  78: 'now and then',
#  79: 'now and then',
#  80: 'now and then',
#  81: 'persuasion',
#  82: 'persuasion',
#  83: 'persuasion',
#  84: 'la cité des enfants perdus',
#  85: 'la cité des enfants perdus',
#  86: 'la cité des enfants perdus',
#  87: '摇啊摇，摇到外婆桥',
#  88: '摇啊摇，摇到外婆桥',
#  89: '摇啊摇，摇到外婆桥',
#  90: 'dangerous minds',
#  91: 'dangerous minds',
#  92: 'dangerous minds',
#  93: 'twelve monkeys',
#  94: 'twelve monkeys',
#  95: 'twelve monkeys',
#  96: 'guillaumet, les ailes du courage',
#  97: 'guillaumet, les ailes du courage',
#  98: 'guillaumet, les ailes du courage',
#  99: 'babe',
#  100: 'babe',
#  101: 'babe',
#  102: 'carrington',
#  103: 'carrington',
#  104: 'carrington',
#  105: 'dead man walking',
#  106: 'dead man walking',
#  107: 'dead man walking',
#  108: 'across the sea of time',
#  109: 'across the sea of time',
#  110: 'across the sea of time',
#  111: 'it takes two',
#  112: 'it takes two',
#  113: 'it takes two',
#  114: 'clueless',
#  115: 'clueless',
#  116: 'clueless',
#  117: 'cry, the beloved country',
#  118: 'cry, the beloved country',
#  119: 'cry, the beloved country',
#  120: 'richard iii',
#  121: 'richard iii',
#  122: 'richard iii',
#  123: 'dead presidents',
#  124: 'dead presidents',
#  125: 'dead presidents',
#  126: 'restoration',
#  127: 'restoration',
#  128: 'restoration',
#  129: 'mortal kombat',
#  130: 'mortal kombat',
#  131: 'mortal kombat',
#  132: 'to die for',
#  133: 'to die for',
#  134: 'to die for',
#  135: 'how to make an american quilt',
#  136: 'how to make an american quilt',
#  137: 'how to make an american quilt',
#  138: 'se7en',
#  139: 'se7en',
#  140: 'se7en',
#  141: 'pocahontas',
#  142: 'pocahontas',
#  143: 'pocahontas',
#  144: 'when night is falling',
#  145: 'when night is falling',
#  146: 'when night is falling',
#  147: 'the usual suspects',
#  148: 'the usual suspects',
#  149: 'the usual suspects',
#  150: 'guardian angel',
#  151: 'guardian angel',
#  152: 'guardian angel',
#  153: 'mighty aphrodite',
#  154: 'mighty aphrodite',
#  155: 'mighty aphrodite',
#  156: 'lamerica',
#  157: 'lamerica',
#  158: 'lamerica',
#  159: 'the big green',
#  160: 'the big green',
#  161: 'the big green',
#  162: 'georgia',
#  163: 'georgia',
#  164: 'georgia',
#  165: 'kids of the round table',
#  166: 'kids of the round table',
#  167: 'kids of the round table',
#  168: 'home for the holidays',
#  169: 'home for the holidays',
#  170: 'home for the holidays',
#  171: 'il postino',
#  172: 'il postino',
#  173: 'il postino',
#  174: 'le confessionnal',
#  175: 'le confessionnal',
#  176: 'le confessionnal',
#  177: 'the indian in the cupboard',
#  178: 'the indian in the cupboard',
#  179: 'the indian in the cupboard',
#  180: 'eye for an eye',
#  181: 'eye for an eye',
#  182: 'eye for an eye',
#  183: "mr. holland's opus",
#  184: "mr. holland's opus",
#  185: "mr. holland's opus",
#  186: "don't be a menace to south central while drinking your juice in the hood",
#  187: "don't be a menace to south central while drinking your juice in the hood",
#  188: "don't be a menace to south central while drinking your juice in the hood",
#  189: 'two if by sea',
#  190: 'two if by sea',
#  191: 'two if by sea',
#  192: 'bio-dome',
#  193: 'bio-dome',
#  194: 'bio-dome',
#  195: 'lawnmower man 2: beyond cyberspace',
#  196: 'lawnmower man 2: beyond cyberspace',
#  197: 'lawnmower man 2: beyond cyberspace',
#  198: 'two bits',
#  199: 'two bits',
#  200: 'two bits',
#  201: 'gazon maudit',
#  202: 'gazon maudit',
#  203: 'gazon maudit',
#  204: 'friday',
#  205: 'friday',
#  206: 'friday',
#  207: 'from dusk till dawn',
#  208: 'from dusk till dawn',
#  209: 'from dusk till dawn',
#  210: 'fair game',
#  211: 'fair game',
#  212: 'fair game',
#  213: 'kicking and screaming',
#  214: 'kicking and screaming',
#  215: 'kicking and screaming',
#  216: 'les misérables',
#  217: 'les misérables',
#  218: 'les misérables',
#  219: 'bed of roses',
#  220: 'bed of roses',
#  221: 'bed of roses',
#  222: 'big bully',
#  223: 'big bully',
#  224: 'big bully',
#  225: 'screamers',
#  226: 'screamers',
#  227: 'screamers',
#  228: 'nico icon',
#  229: 'nico icon',
#  230: 'nico icon',
#  231: 'the crossing guard',
#  232: 'the crossing guard',
#  233: 'the crossing guard',
#  234: 'the juror',
#  235: 'the juror',
#  236: 'the juror',
#  237: 'بادکنک سفید',
#  238: 'بادکنک سفید',
#  239: 'بادکنک سفید',
#  240: "things to do in denver when you're dead",
#  241: "things to do in denver when you're dead",
#  242: "things to do in denver when you're dead",
#  243: 'antonia',
#  244: 'antonia',
#  245: 'antonia',
#  246: 'once upon a time... when we were colored',
#  247: 'once upon a time... when we were colored',
#  248: 'once upon a time... when we were colored',
#  249: 'last summer in the hamptons',
#  250: 'last summer in the hamptons',
#  251: 'last summer in the hamptons',
#  252: 'angels and insects',
#  253: 'angels and insects',
#  254: 'angels and insects',
#  255: 'white squall',
#  256: 'white squall',
#  257: 'white squall',
#  258: 'dunston checks in',
#  259: 'dunston checks in',
#  260: 'dunston checks in',
#  261: 'black sheep',
#  262: 'black sheep',
#  263: 'black sheep',
#  264: 'nick of time',
#  265: 'nick of time',
#  266: 'nick of time',
#  267: 'the journey of august king',
#  268: 'the journey of august king',
#  269: 'the journey of august king',
#  270: 'mary reilly',
#  271: 'mary reilly',
#  272: 'mary reilly',
#  273: 'vampire in brooklyn',
#  274: 'vampire in brooklyn',
#  275: 'vampire in brooklyn',
#  276: 'beautiful girls',
#  277: 'beautiful girls',
#  278: 'beautiful girls',
#  279: 'broken arrow',
#  280: 'broken arrow',
#  281: 'broken arrow',
#  282: "a midwinter's tale",
#  283: "a midwinter's tale",
#  284: "a midwinter's tale",
#  285: 'la haine',
#  286: 'la haine',
#  287: 'la haine',
#  288: 'shopping',
#  289: 'shopping',
#  290: 'shopping',
#  291: 'heidi fleiss: hollywood madam',
#  292: 'heidi fleiss: hollywood madam',
#  293: 'heidi fleiss: hollywood madam',
#  294: 'city hall',
#  295: 'city hall',
#  296: 'city hall',
#  297: 'bottle rocket',
#  298: 'bottle rocket',
#  299: 'bottle rocket',
#  300: 'mr. wrong',
#  301: 'mr. wrong',
#  302: 'mr. wrong',
#  303: 'unforgettable',
#  304: 'unforgettable',
#  305: 'unforgettable',
#  306: 'happy gilmore',
#  307: 'happy gilmore',
#  308: 'happy gilmore',
#  309: 'the bridges of madison county',
#  310: 'the bridges of madison county',
#  311: 'the bridges of madison county',
#  312: 'keiner liebt mich',
#  313: 'keiner liebt mich',
#  314: 'keiner liebt mich',
#  315: 'muppet treasure island',
#  316: 'muppet treasure island',
#  317: 'muppet treasure island',
#  318: 'catwalk',
#  319: 'catwalk',
#  320: 'catwalk',
#  321: 'headless body in topless bar',
#  322: 'headless body in topless bar',
#  323: 'headless body in topless bar',
#  324: 'braveheart',
#  325: 'braveheart',
#  326: 'braveheart',
#  327: 'taxi driver',
#  328: 'taxi driver',
#  329: 'taxi driver',
#  330: '紅番區',
#  331: '紅番區',
#  332: '紅番區',
#  333: 'before and after',
#  334: 'before and after',
#  335: 'before and after',
#  336: "margaret's museum",
#  337: "margaret's museum",
#  338: "margaret's museum",
#  339: 'le bonheur est dans le pré',
#  340: 'le bonheur est dans le pré',
#  341: 'le bonheur est dans le pré',
#  342: 'anne frank remembered',
#  343: 'anne frank remembered',
#  344: 'anne frank remembered',
#  345: "the young poisoner's handbook",
#  346: "the young poisoner's handbook",
#  347: "the young poisoner's handbook",
#  348: 'if lucy fell',
#  349: 'if lucy fell',
#  350: 'if lucy fell',
#  351: 'steal big steal little',
#  352: 'steal big steal little',
#  353: 'steal big steal little',
#  354: 'race the sun',
#  355: 'race the sun',
#  356: 'race the sun',
#  357: 'the boys of st. vincent',
#  358: 'the boys of st. vincent',
#  359: 'the boys of st. vincent',
#  360: 'boomerang',
#  361: 'boomerang',
#  362: 'boomerang',
#  363: '重慶森林',
#  364: '重慶森林',
#  365: '重慶森林',
#  366: "l'uomo delle stelle",
#  367: "l'uomo delle stelle",
#  368: "l'uomo delle stelle",
#  369: 'flirting with disaster',
#  370: 'flirting with disaster',
#  371: 'flirting with disaster',
#  372: 'the neverending story iii',
#  373: 'the neverending story iii',
#  374: 'the neverending story iii',
#  375: 'صمت القصور',
#  376: 'صمت القصور',
#  377: 'صمت القصور',
#  378: "jupiter's wife",
#  379: "jupiter's wife",
#  380: "jupiter's wife",
#  381: 'pie in the sky',
#  382: 'pie in the sky',
#  383: 'pie in the sky',
#  384: 'angela',
#  385: 'angela',
#  386: 'angela',
#  387: 'frankie starlight',
#  388: 'frankie starlight',
#  389: 'frankie starlight',
#  390: 'jade',
#  391: 'jade',
#  392: 'jade',
#  393: 'nueba yol',
#  394: 'nueba yol',
#  395: 'nueba yol',
#  396: 'sonic outlaws',
#  397: 'sonic outlaws',
#  398: 'sonic outlaws',
#  399: 'down periscope',
#  400: 'down periscope',
#  401: 'down periscope',
#  402: 'from the journals of jean seberg',
#  403: 'from the journals of jean seberg',
#  404: 'from the journals of jean seberg',
#  405: 'man of the year',
#  406: 'man of the year',
#  407: 'man of the year',
#  408: 'the neon bible',
#  409: 'the neon bible',
#  410: 'the neon bible',
#  411: 'target',
#  412: 'target',
#  413: 'target',
#  414: 'up close & personal',
#  415: 'up close & personal',
#  416: 'up close & personal',
#  417: 'the birdcage',
#  418: 'the birdcage',
#  419: 'the birdcage',
#  420: 'gospa',
#  421: 'gospa',
#  422: 'gospa',
#  423: 'the brothers mcmullen',
#  424: 'the brothers mcmullen',
#  425: 'the brothers mcmullen',
#  426: 'bad boys',
#  427: 'bad boys',
#  428: 'bad boys',
#  429: 'the amazing panda adventure',
#  430: 'the amazing panda adventure',
#  431: 'the amazing panda adventure',
#  432: 'the basketball diaries',
#  433: 'the basketball diaries',
#  434: 'the basketball diaries',
#  435: 'an awfully big adventure',
#  436: 'an awfully big adventure',
#  437: 'an awfully big adventure',
#  438: 'amateur',
#  439: 'amateur',
#  440: 'amateur',
#  441: 'apollo 13',
#  442: 'apollo 13',
#  443: 'apollo 13',
#  444: 'rob roy',
#  445: 'rob roy',
#  446: 'rob roy',
#  447: 'the addiction',
#  448: 'the addiction',
#  449: 'the addiction',
#  450: 'batman forever',
#  451: 'batman forever',
#  452: 'batman forever',
#  453: 'belle de jour',
#  454: 'belle de jour',
#  455: 'belle de jour',
#  456: 'beyond rangoon',
#  457: 'beyond rangoon',
#  458: 'beyond rangoon',
#  459: 'blue in the face',
#  460: 'blue in the face',
#  461: 'blue in the face',
#  462: 'canadian bacon',
#  463: 'canadian bacon',
#  464: 'canadian bacon',
#  465: 'casper',
#  466: 'casper',
#  467: 'casper',
#  468: 'clockers',
#  469: 'clockers',
#  470: 'clockers',
#  471: 'congo',
#  472: 'congo',
#  473: 'congo',
#  474: 'crimson tide',
#  475: 'crimson tide',
#  476: 'crimson tide',
#  477: 'crumb',
#  478: 'crumb',
#  479: 'crumb',
#  480: 'desperado',
#  481: 'desperado',
#  482: 'desperado',
#  483: 'devil in a blue dress',
#  484: 'devil in a blue dress',
#  485: 'devil in a blue dress',
#  486: 'die hard: with a vengeance',
#  487: 'die hard: with a vengeance',
#  488: 'die hard: with a vengeance',
#  489: 'the doom generation',
#  490: 'the doom generation',
#  491: 'the doom generation',
#  492: 'feast of july',
#  493: 'feast of july',
#  494: 'feast of july',
#  495: 'first knight',
#  496: 'first knight',
#  497: 'first knight',
#  498: 'free willy 2 - the adventure home',
#  499: 'free willy 2 - the adventure home',
#  500: 'free willy 2 - the adventure home',
#  501: 'hackers',
#  502: 'hackers',
#  503: 'hackers',
#  504: 'jeffrey',
#  505: 'jeffrey',
#  506: 'jeffrey',
#  507: 'johnny mnemonic',
#  508: 'johnny mnemonic',
#  509: 'johnny mnemonic',
#  510: 'judge dredd',
#  511: 'judge dredd',
#  512: 'judge dredd',
#  513: 'jury duty',
#  514: 'jury duty',
#  515: 'jury duty',
#  516: 'kids',
#  517: 'kids',
#  518: 'kids',
#  519: 'living in oblivion',
#  520: 'living in oblivion',
#  521: 'living in oblivion',
#  522: 'lord of illusions',
#  523: 'lord of illusions',
#  524: 'lord of illusions',
#  525: 'love & human remains',
#  526: 'love & human remains',
#  527: 'love & human remains',
#  528: 'mad love',
#  529: 'mad love',
#  530: 'mad love',
#  531: 'mallrats',
#  532: 'mallrats',
#  533: 'mallrats',
#  534: 'mighty morphin power rangers: the movie',
#  535: 'mighty morphin power rangers: the movie',
#  536: 'mighty morphin power rangers: the movie',
#  537: 'moonlight and valentino',
#  538: 'moonlight and valentino',
#  539: 'moonlight and valentino',
#  540: 'mute witness',
#  541: 'mute witness',
#  542: 'mute witness',
#  543: 'nadja',
#  544: 'nadja',
#  545: 'nadja',
#  546: 'the net',
#  547: 'the net',
#  548: 'the net',
#  549: 'nine months',
#  550: 'nine months',
#  551: 'nine months',
#  552: 'party girl',
#  553: 'party girl',
#  554: 'party girl',
#  555: 'the prophecy',
#  556: 'the prophecy',
#  557: 'the prophecy',
#  558: 'reckless',
#  559: 'reckless',
#  560: 'reckless',
#  561: 'safe',
#  562: 'safe',
#  563: 'safe',
#  564: 'the scarlet letter',
#  565: 'the scarlet letter',
#  566: 'the scarlet letter',
#  567: 'the show',
#  568: 'the show',
#  569: 'the show',
#  570: 'showgirls',
#  571: 'showgirls',
#  572: 'showgirls',
#  573: 'smoke',
#  574: 'smoke',
#  575: 'smoke',
#  576: 'something to talk about',
#  577: 'something to talk about',
#  578: 'something to talk about',
#  579: 'species',
#  580: 'species',
#  581: 'species',
#  582: 'the stars fell on henrietta',
#  583: 'the stars fell on henrietta',
#  584: 'the stars fell on henrietta',
#  585: 'strange days',
#  586: 'strange days',
#  587: 'strange days',
#  588: 'les parapluies de cherbourg',
#  589: 'les parapluies de cherbourg',
#  590: 'les parapluies de cherbourg',
#  591: 'the tie that binds',
#  592: 'the tie that binds',
#  593: 'the tie that binds',
#  594: 'three wishes',
#  595: 'three wishes',
#  596: 'three wishes',
#  597: 'total eclipse',
#  598: 'total eclipse',
#  599: 'total eclipse',
#  600: 'to wong foo, thanks for everything! julie newmar',
#  601: 'to wong foo, thanks for everything! julie newmar',
#  602: 'to wong foo, thanks for everything! julie newmar',
#  603: 'under siege 2: dark territory',
#  604: 'under siege 2: dark territory',
#  605: 'under siege 2: dark territory',
#  606: 'unstrung heroes',
#  607: 'unstrung heroes',
#  608: 'unstrung heroes',
#  609: 'unzipped',
#  610: 'unzipped',
#  611: 'unzipped',
#  612: 'a walk in the clouds',
#  613: 'a walk in the clouds',
#  614: 'a walk in the clouds',
#  615: 'waterworld',
#  616: 'waterworld',
#  617: 'waterworld',
#  618: "white man's burden",
#  619: "white man's burden",
#  620: "white man's burden",
#  621: 'wild bill',
#  622: 'wild bill',
#  623: 'wild bill',
#  624: 'the browning version',
#  625: 'the browning version',
#  626: 'the browning version',
#  627: 'bushwhacked',
#  628: 'bushwhacked',
#  629: 'bushwhacked',
#  630: 'утомлённые солнцем',
#  631: 'утомлённые солнцем',
#  632: 'утомлённые солнцем',
#  633: 'before the rain',
#  634: 'before the rain',
#  635: 'before the rain',
#  636: 'before sunrise',
#  637: 'before sunrise',
#  638: 'before sunrise',
#  639: 'billy madison',
#  640: 'billy madison',
#  641: 'billy madison',
#  642: 'the babysitter',
#  643: 'the babysitter',
#  644: 'the babysitter',
#  645: 'boys on the side',
#  646: 'boys on the side',
#  647: 'boys on the side',
#  648: 'the cure',
#  649: 'the cure',
#  650: 'the cure',
#  651: 'castle freak',
#  652: 'castle freak',
#  653: 'castle freak',
#  654: 'circle of friends',
#  655: 'circle of friends',
#  656: 'circle of friends',
#  657: 'clerks',
#  658: 'clerks',
#  659: 'clerks',
#  660: 'don juan demarco',
#  661: 'don juan demarco',
#  662: 'don juan demarco',
#  663: 'disclosure',
#  664: 'disclosure',
#  665: 'disclosure',
#  666: 'dream man',
#  667: 'dream man',
#  668: 'dream man',
#  669: 'drop zone',
#  670: 'drop zone',
#  671: 'drop zone',
#  672: 'destiny turns on the radio',
#  673: 'destiny turns on the radio',
#  674: 'destiny turns on the radio',
#  675: 'death and the maiden',
#  676: 'death and the maiden',
#  677: 'death and the maiden',
#  678: 'dolores claiborne',
#  679: 'dolores claiborne',
#  680: 'dolores claiborne',
#  681: 'dumb and dumber',
#  682: 'dumb and dumber',
#  683: 'dumb and dumber',
#  684: '飲食男女',
#  685: '飲食男女',
#  686: '飲食男女',
#  687: 'exotica',
#  688: 'exotica',
#  689: 'exotica',
#  690: 'exit to eden',
#  691: 'exit to eden',
#  692: 'exit to eden',
#  693: 'ed wood',
#  694: 'ed wood',
#  695: 'ed wood',
#  696: 'french kiss',
#  697: 'french kiss',
#  698: 'french kiss',
#  699: 'forget paris',
#  700: 'forget paris',
#  701: 'forget paris',
#  702: 'far from home: the adventures of yellow dog',
#  703: 'far from home: the adventures of yellow dog',
#  704: 'far from home: the adventures of yellow dog',
#  705: 'a goofy movie',
#  706: 'a goofy movie',
#  707: 'a goofy movie',
#  708: 'hideaway',
#  709: 'hideaway',
#  710: 'hideaway',
#  711: 'fluke',
#  712: 'fluke',
#  713: 'fluke',
#  714: 'farinelli',
#  715: 'farinelli',
#  716: 'farinelli',
#  717: 'gordy',
#  718: 'gordy',
#  719: 'gordy',
#  720: 'gumby: the movie',
#  721: 'gumby: the movie',
#  722: 'gumby: the movie',
#  723: 'the glass shield',
#  724: 'the glass shield',
#  725: 'the glass shield',
#  726: 'hoop dreams',
#  727: 'hoop dreams',
#  728: 'hoop dreams',
#  729: 'heavenly creatures',
#  730: 'heavenly creatures',
#  731: 'heavenly creatures',
#  732: 'houseguest',
#  733: 'houseguest',
#  734: 'houseguest',
#  735: 'immortal beloved',
#  736: 'immortal beloved',
#  737: 'immortal beloved',
#  738: 'heavyweights',
#  739: 'heavyweights',
#  740: 'heavyweights',
#  741: 'the hunted',
#  742: 'the hunted',
#  743: 'the hunted',
#  744: 'i.q.',
#  745: 'i.q.',
#  746: 'i.q.',
#  747: 'interview with the vampire',
#  748: 'interview with the vampire',
#  749: 'interview with the vampire',
#  750: 'jefferson in paris',
#  751: 'jefferson in paris',
#  752: 'jefferson in paris',
#  753: 'the jerky boys',
#  754: 'the jerky boys',
#  755: 'the jerky boys',
#  756: 'junior',
#  757: 'junior',
#  758: 'junior',
#  759: 'just cause',
#  760: 'just cause',
#  761: 'just cause',
#  762: "a kid in king arthur's court",
#  763: "a kid in king arthur's court",
#  764: "a kid in king arthur's court",
#  765: 'kiss of death',
#  766: 'kiss of death',
#  767: 'kiss of death',
#  768: 'star wars',
#  769: 'star wars',
#  770: 'star wars',
#  771: 'little women',
#  772: 'little women',
#  773: 'little women',
#  774: 'a little princess',
#  775: 'a little princess',
#  776: 'a little princess',
#  777: 'ladybird ladybird',
#  778: 'ladybird ladybird',
#  779: 'ladybird ladybird',
#  780: "l'enfer",
#  781: "l'enfer",
#  782: "l'enfer",
#  783: 'como agua para chocolate',
#  784: 'como agua para chocolate',
#  785: 'como agua para chocolate',
#  786: 'legends of the fall',
#  787: 'legends of the fall',
#  788: 'legends of the fall',
#  789: 'major payne',
#  790: 'major payne',
#  791: 'major payne',
#  792: 'little odessa',
#  793: 'little odessa',
#  794: 'little odessa',
#  795: 'mi vida loca',
#  796: 'mi vida loca',
#  797: 'mi vida loca',
#  798: 'love affair',
#  799: 'love affair',
#  800: 'love affair',
#  801: 'losing isaiah',
#  802: 'losing isaiah',
#  803: 'losing isaiah',
#  804: 'the madness of king george',
#  805: 'the madness of king george',
#  806: 'the madness of king george',
#  807: 'frankenstein',
#  808: 'frankenstein',
#  809: 'frankenstein',
#  810: 'man of the house',
#  811: 'man of the house',
#  812: 'man of the house',
#  813: 'mixed nuts',
#  814: 'mixed nuts',
#  815: 'mixed nuts',
#  816: 'milk money',
#  817: 'milk money',
#  818: 'milk money',
#  819: 'miracle on 34th street',
#  820: 'miracle on 34th street',
#  821: 'miracle on 34th street',
#  822: 'miami rhapsody',
#  823: 'miami rhapsody',
#  824: 'miami rhapsody',
#  825: 'my family',
#  826: 'my family',
#  827: 'my family',
#  828: 'murder in the first',
#  829: 'murder in the first',
#  830: 'murder in the first',
#  831: "nobody's fool",
#  832: "nobody's fool",
#  833: "nobody's fool",
#  834: 'nell',
#  835: 'nell',
#  836: 'nell',
#  837: 'new jersey drive',
#  838: 'new jersey drive',
#  839: 'new jersey drive',
#  840: 'new york cop',
#  841: 'new york cop',
#  842: 'new york cop',
#  843: 'beyond bedlam',
#  844: 'beyond bedlam',
#  845: 'beyond bedlam',
#  846: 'nemesis 2 - nebula',
#  847: 'nemesis 2 - nebula',
#  848: 'nemesis 2 - nebula',
#  849: 'nina takes a lover',
#  850: 'nina takes a lover',
#  851: 'nina takes a lover',
#  852: 'natural born killers',
#  853: 'natural born killers',
#  854: 'natural born killers',
#  855: 'only you',
#  856: 'only you',
#  857: 'only you',
#  858: 'once were warriors',
#  859: 'once were warriors',
#  860: 'once were warriors',
#  861: 'poison ivy ii: lily',
#  862: 'poison ivy ii: lily',
#  863: 'poison ivy ii: lily',
#  864: 'outbreak',
#  865: 'outbreak',
#  866: 'outbreak',
#  867: 'léon',
#  868: 'léon',
#  869: 'léon',
#  870: 'the perez family',
#  871: 'the perez family',
#  872: 'the perez family',
#  873: "a pyromaniac's love story",
#  874: "a pyromaniac's love story",
#  875: "a pyromaniac's love story",
#  876: 'pulp fiction',
#  877: 'pulp fiction',
#  878: 'pulp fiction',
#  879: 'panther',
#  880: 'panther',
#  881: 'panther',
#  882: 'pushing hands',
#  883: 'pushing hands',
#  884: 'pushing hands',
#  885: 'priest',
#  886: 'priest',
#  887: 'priest',
#  888: 'quiz show',
#  889: 'quiz show',
#  890: 'quiz show',
#  891: 'picture bride',
#  892: 'picture bride',
#  893: 'picture bride',
#  894: 'la reine margot',
#  895: 'la reine margot',
#  896: 'la reine margot',
#  897: 'the quick and the dead',
#  898: 'the quick and the dead',
#  899: 'the quick and the dead',
#  900: 'roommates',
#  901: 'roommates',
#  902: 'roommates',
#  903: 'prêt-à-porter',
#  904: 'prêt-à-porter',
#  905: 'prêt-à-porter',
#  906: 'trois couleurs : rouge',
#  907: 'trois couleurs : rouge',
#  908: 'trois couleurs : rouge',
#  909: 'trois couleurs : bleu',
#  910: 'trois couleurs : bleu',
#  911: 'trois couleurs : bleu',
#  912: 'trois couleurs : blanc',
#  913: 'trois couleurs : blanc',
#  914: 'trois couleurs : blanc',
#  915: 'pao da shuang deng',
#  916: 'pao da shuang deng',
#  917: 'pao da shuang deng',
#  918: 'rent-a-kid',
#  919: 'rent-a-kid',
#  920: 'rent-a-kid',
#  921: 'relative fear',
#  922: 'relative fear',
#  923: 'relative fear',
#  924: 'stuart saves his family',
#  925: 'stuart saves his family',
#  926: 'stuart saves his family',
#  927: 'the swan princess',
#  928: 'the swan princess',
#  929: 'the swan princess',
#  930: 'the secret of roan inish',
#  931: 'the secret of roan inish',
#  932: 'the secret of roan inish',
#  933: 'the specialist',
#  934: 'the specialist',
#  935: 'the specialist',
#  936: 'stargate',
#  937: 'stargate',
#  938: 'stargate',
#  939: 'the santa clause',
#  940: 'the santa clause',
#  941: 'the santa clause',
#  942: 'the shawshank redemption',
#  943: 'the shawshank redemption',
#  944: 'the shawshank redemption',
#  945: 'shallow grave',
#  946: 'shallow grave',
#  947: 'shallow grave',
#  948: 'suture',
#  949: 'suture',
#  950: 'suture',
#  951: 'fresa y chocolate',
#  952: 'fresa y chocolate',
#  953: 'fresa y chocolate',
#  954: 'swimming with sharks',
#  955: 'swimming with sharks',
#  956: 'swimming with sharks',
#  957: 'the sum of us',
#  958: 'the sum of us',
#  959: 'the sum of us',
#  960: 'senior trip',
#  961: 'senior trip',
#  962: 'senior trip',
#  963: '活着',
#  964: '活着',
#  965: '活着',
#  966: 'tank girl',
#  967: 'tank girl',
#  968: 'tank girl',
#  969: 'tales from the crypt: demon knight',
#  970: 'tales from the crypt: demon knight',
#  971: 'tales from the crypt: demon knight',
#  972: 'star trek: generations',
#  973: 'star trek: generations',
#  974: 'star trek: generations',
#  975: 'tales from the hood',
#  976: 'tales from the hood',
#  977: 'tales from the hood',
#  978: 'tom & viv',
#  979: 'tom & viv',
#  980: 'tom & viv',
#  981: 'village of the damned',
#  982: 'village of the damned',
#  983: 'village of the damned',
#  984: 'tommy boy',
#  985: 'tommy boy',
#  986: 'tommy boy',
#  987: 'vanya on 42nd street',
#  988: 'vanya on 42nd street',
#  989: 'vanya on 42nd street',
#  990: 'the underneath',
#  991: 'the underneath',
#  992: 'the underneath',
#  993: 'the walking dead',
#  994: 'the walking dead',
#  995: 'the walking dead',
#  996: "what's eating gilbert grape",
#  997: "what's eating gilbert grape",
#  998: "what's eating gilbert grape",
#  999: 'virtuosity',
#  ...}

# %%
output['title_name'] = output['model_index'].astype(int).map(name_mapper)
output
# Out:
#    model_index  model_score                         title_name
# 0         1756     1.000000                             batman
# 1       113215     0.974853         curse of the crimson altar
# 2        32779     0.974840                           beerfest
# 3        81125     0.974784                             12 + 1
# 4        29341     0.974576                    mysterious skin
# 5        99229     0.974541                      famous nathan
# 6        77246     0.974404                            rosalie
# 7        43451     0.974252                        torrid zone
# 8        32108     0.974220                   peaceful warrior
# 9        74875     0.974041              shortcut to happiness
# 10      130568     0.973894                                NaN
# 11      113617     0.973584                    أسف علي الازعاج
# 12       72794     0.973552                                파수꾼
# 13      107381     0.973502                        sunset song
# 14      113940     0.973442  johan falk: organizatsija karayan
# 15        4135     0.973440              falling in love again
# 16      105410     0.973365                   días de santiago
# 17       77176     0.973352                         io sono li
# 18       46504     0.973352          jerry springer: the opera
# 19      131537     0.973338                                NaN

# %% [markdown]
# # TODO

# %% [markdown]
# - Add `original_title`, `keywords`, `tagline` and other metadata to train sample and then retrain embeddings;
# - Make visualization of embeddings with links of films with each other;
# - Compare results with the embeddings we created in lecture
# - Write function get_recommendations() which takes arguments we used 2.3., but such that we can use embeddings of several watched films to get recommendations

# %% [markdown]
# # Appendix

# %% [markdown]
# Here, we wrap up all pipeline into functions to re-use if needed and it is just prettier to code this way :)

# %%
def get_clean_tags_array(agg_tags: pd.DataFrame,
                         text_col = 'tag'):
    '''text preprocessing
    '''
    tags_corpus = agg_tags[text_col].values
    tags_corpus = [re.sub('-[!/()0-9]', '', x) for x in tags_corpus]
    stop_words = stopwords.words('english')


    # preprocess corpus of movie tags before feeding it into Doc2Vec model
    tags_doc = [TaggedDocument(words = word_tokenize_clean(D, stop_words), tags = [str(i)]) for i, D in enumerate(tags_corpus)]

    return tags_doc

# %%
def train_embeddings(tags_doc: np.array,
                     epochs = 20,
                     vec_size = 50,
                     alpha = .02,
                     min_alpha =  0.00025,
                     min_count = 5,
                     save_path: str = None):
    """
    fit doc2vec model to prepared corpus
    :tags_doc: result of get_clean_tags_array()
    :max_epocs: int
    :vec_size: int
    :alpha: float
    """
    #initialize
    model = Doc2Vec(vector_size = vec_size,
                    alpha = alpha, 
                    min_alpha = min_alpha,
                    min_count = min_count,
                    dm = 0)
    
    #generate vocab from all tag docs
    model.build_vocab(tags_doc)
    
    #train model
    model.train(tags_doc,
                total_examples = model.corpus_count,
                epochs = epochs)
    
    #save model to dir
    if save_path:
        model.save(f'{save_path}/d2v_model.pkl')
    
    return model
